# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikar5321-boop/AI-Practical-Assignments/blob/main/Assignment7_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt

data = load_breast_cancer()
X = data.data
y = data.target

model = RandomForestClassifier(n_estimators=100, oob_score=True)
model.fit(X, y)

print("OOB Score:", model.oob_score_)

plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
plt.title("Feature Importance")
plt.show()
# Out:
# OOB Score: 0.9595782073813708
