# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikar5321-boop/AI-Practical-Assignments/blob/main/Assignment4_PCA%2BKmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

data = load_iris()
X = data.data
y = data.target

# Without PCA
kmeans = KMeans(n_clusters=3)
labels1 = kmeans.fit_predict(X)

# With PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

kmeans2 = KMeans(n_clusters=3)
labels2 = kmeans2.fit_predict(X_pca)

print("ARI without PCA:", adjusted_rand_score(y, labels1))
print("ARI with PCA:", adjusted_rand_score(y, labels2))
# Out:
# ARI without PCA: 0.7302382722834697
# ARI with PCA: 0.7163421126838476
