# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikar5321-boop/AI-Practical-Assignments/blob/main/Assignment3_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import numpy as np

data = load_digits()
X = data.data
y = data.target

# PCA 2D
pca = PCA(n_components=2)
X_2D = pca.fit_transform(X)

plt.scatter(X_2D[:,0], X_2D[:,1], c=y)
plt.title("2D PCA")
plt.show()

# Explained variance
pca_full = PCA()
pca_full.fit(X)

cum_var = np.cumsum(pca_full.explained_variance_ratio_)

plt.plot(cum_var)
plt.title("Cumulative Variance")
plt.show()
