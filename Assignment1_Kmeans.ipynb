# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikar5321-boop/AI-Practical-Assignments/blob/main/Assignment1_Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs

# Create synthetic dataset
X, _ = make_blobs(n_samples=300, centers=5, random_state=42)

# Elbow Method
wcss = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,10), wcss)
plt.title("Elbow Method")
plt.xlabel("Clusters")
plt.ylabel("WCSS")
plt.show()

# Silhouette Score
for i in range(2, 10):
    kmeans = KMeans(n_clusters=i)
    labels = kmeans.fit_predict(X)
    print(f"Clusters={i}, Silhouette Score={silhouette_score(X, labels)}")

# Final Model
kmeans = KMeans(n_clusters=5)
labels = kmeans.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=labels)
plt.title("Customer Segments")
plt.show()
# Out:
# Clusters=2, Silhouette Score=0.479214091923145
# Clusters=3, Silhouette Score=0.710855406273307
# Clusters=4, Silhouette Score=0.5804129226609305
# Clusters=5, Silhouette Score=0.6586478247336219
# Clusters=6, Silhouette Score=0.5421819053229101
# Clusters=7, Silhouette Score=0.5961178276856448
# Clusters=8, Silhouette Score=0.3952821712429832
# Clusters=9, Silhouette Score=0.4408573969958087
